# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from fractal_analysis import estimator
from fractal_analysis.estimator.hurst_estimator import IrHurstEstimator, QvHurstEstimator

# %%
nik225 = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/nikkei225_daily_close_201412_202512.xlsx")
nik_vol = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/Nikkei_Volatility_Historical_Data.xlsx")
interest = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/jgb_10y_yield_daily_201412_202512.xlsx")

# %%
NIK225 = nik225['log_price']
NIK_vol = nik_vol['log_vol']
Interest = interest['log_interest']

# %%
a = nik225['date']
y = NIK225
x = pd.to_datetime(a)
plt.plot(x, y)
plt.plot([x[392], x[392]], [9.5, 11], color='red', linestyle='--', linewidth=0.8)
plt.annotate('07/2016',xy = (x[392],11), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1253], x[1253]], [9.5, 11], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2020',xy = (x[1253],9.5), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1515], x[1515]], [9.5, 11], color='red', linestyle='--', linewidth=0.8)
plt.annotate('02/2021',xy = (x[1515],11), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1975], x[1975]], [9.5, 11], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2023',xy = (x[1975],9.5), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[2365], x[2365]], [9.5, 11], color='red', linestyle='--', linewidth=0.8)
plt.annotate('08/2024',xy = (x[2365],11), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.title("Nikkei225")
plt.xlabel("Date")
plt.ylabel("Nikkei225 index")
plt.show()

# %%
b = interest['date']
y = Interest
x = pd.to_datetime(b)
plt.plot(x, y)
plt.plot([x[404], x[404]], [-4.5, 1], color='red', linestyle='--', linewidth=0.8)
plt.annotate('07/2016',xy = (x[404],-4.5), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1253], x[1253]], [-4.5, 1], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2020',xy = (x[1253],1), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1522], x[1522]], [-4.5, 1], color='red', linestyle='--', linewidth=0.8)
plt.annotate('02/2021',xy = (x[1522],-4.5), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1986], x[1986]], [-4.5, 1], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2023',xy = (x[1986],1), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[2363], x[2363]], [-4.5, 1], color='red', linestyle='--', linewidth=0.8)
plt.annotate('08/2024',xy = (x[2363],-4.5), horizontalalignment = 'center', verticalalignment = 'top')
plt.title("Interest rate")
plt.xlabel("Date")
plt.ylabel("Yield on the 10-year government bond")
plt.show()

# %%
c = nik_vol['Date']
y = NIK_vol
x = pd.to_datetime(c)
plt.plot(x, y)
plt.plot([x[392], x[392]], [2.4, 4.3], color='red', linestyle='--', linewidth=0.8)
plt.annotate('07/2016',xy = (x[392],4.3), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1251], x[1251]], [2.4, 4.3], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2020',xy = (x[1251],2.4), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1509], x[1509]], [2.4, 4.3], color='red', linestyle='--', linewidth=0.8)
plt.annotate('02/2021',xy = (x[1509],4.3), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1986], x[1986]], [2.4, 4.3], color='red', linestyle='--', linewidth=0.8)
plt.annotate('01/2023',xy = (x[1986],2.4), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[2365], x[2365]], [2.4, 4.3], color='red', linestyle='--', linewidth=0.8)
plt.annotate('08/2024',xy = (x[2365],4.3), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.title("Nikkei Volatility")
plt.xlabel("Date")
plt.ylabel("Nikkei Volatility index")
plt.show()

# %%
#Period 1: from December 2014 to July 2016

# %%
NIK225_1 = NIK225[0:392]
NIK_vol_1 = NIK_vol[0:392]
Interest_1 = Interest[0:404]

# %%
QvH_NIK225_1 = QvHurstEstimator(mbm_series=NIK225_1, alpha=0.2)
H1_1 = QvH_NIK225_1.holder_exponents.mean()
print(H1_1)
# Out:
# 0.4995731578777463

# %%
QvH_NIK_vol_1 = QvHurstEstimator(mbm_series=NIK_vol_1, alpha=0.2)
H2_1 = QvH_NIK_vol_1.holder_exponents.mean()
print(H2_1)
# Out:
# 0.49008484654463086

# %%
QvH_Interest_1 = QvHurstEstimator(mbm_series=Interest_1, alpha=0.2)
H3_1 = QvH_Interest_1.holder_exponents.mean()
print(H3_1)
# Out:
# 0.4468863362422697

# %%
max_val = QvH_NIK_vol_6.holder_exponents.max()
min_val = QvH_NIK_vol_6.holder_exponents.min()
print(max_val, min_val)
# Out:
# 0.42948167608451604 0.22855491507175496

# %%
#cross long-term memory

# %%
print(H1_1 + H2_1)    #nikkei225+volatility
print(H1_1 + H3_1)    #nikkei225+interest rate
print(H2_1 + H3_1)    #volatility+interest rate
# Out:
# 0.9896580044223772
# 0.946459494120016
# 0.9369711827869005

# %%
#long-term memory

# %%
print(H1_1 + H1_1)    #nikkei225+nikkei225
print(H2_1 + H2_1)    #volatility+volatility
print(H3_1 + H3_1)    #interest rate+interest rate
# Out:
# 0.9991463157554926
# 0.9801696930892617
# 0.8937726724845394

# %%
#Period 2: from July 2016 to January 2020

# %%
NIK225_2 = NIK225[393:1253]
NIK_vol_2 = NIK_vol[393:1251]
Interest_2 = Interest[405:1253]

# %%
QvH_NIK225_2 = QvHurstEstimator(mbm_series=NIK225_2, alpha=0.2)
H1_2 = QvH_NIK225_2.holder_exponents.mean()
print(H1_2)
# Out:
# 0.47436615381987146

# %%
QvH_NIK_vol_2 = QvHurstEstimator(mbm_series=NIK_vol_2, alpha=0.2)
H2_2 = QvH_NIK_vol_2.holder_exponents.mean()
print(H2_2)
# Out:
# 0.4891620977492727

# %%
QvH_Interest_2 = QvHurstEstimator(mbm_series=Interest_2, alpha=0.2)
H3_2 = QvH_Interest_2.holder_exponents.mean()
print(H3_2)
# Out:
# 0.44599253775203296

# %%
#cross long-term memory

# %%
print(H1_2 + H2_2)    #nikkei225+volatility
print(H1_2 + H3_2)    #nikkei225+interest rate
print(H2_2 + H3_2)    #volatility+interest rate
# Out:
# 0.9635282515691441
# 0.9203586915719044
# 0.9351546355013056

# %%
#long-term memory

# %%
print(H1_2 + H1_2)    #nikkei225+nikkei225
print(H2_2 + H2_2)    #volatility+volatility
print(H3_2 + H3_2)    #interest rate+interest rate
# Out:
# 0.9487323076397429
# 0.9783241954985454
# 0.8919850755040659

# %%
#Period 3: from January 2020 to February 2021

# %%
NIK225_3 = NIK225[1254:1515]
NIK_vol_3 = NIK_vol[1252:1509]
Interest_3 = Interest[1254:1522]

# %%
QvH_NIK225_3 = QvHurstEstimator(mbm_series=NIK225_3, alpha=0.2)
H1_3 = QvH_NIK225_3.holder_exponents.mean()
print(H1_3)
# Out:
# 0.5516063559244471

# %%
QvH_NIK_vol_3 = QvHurstEstimator(mbm_series=NIK_vol_3, alpha=0.2)
H2_3 = QvH_NIK_vol_3.holder_exponents.mean()
print(H2_3)
# Out:
# 0.5043252533264972

# %%
QvH_Interest_3 = QvHurstEstimator(mbm_series=Interest_3, alpha=0.2)
H3_3 = QvH_Interest_3.holder_exponents.mean()
print(H3_3)
# Out:
# 0.3240379892564426

# %%
#cross long-term memory

# %%
print(H1_3 + H2_3)    #nikkei225+volatility
print(H1_3 + H3_3)    #nikkei225+interest rate
print(H2_3 + H3_3)    #volatility+interest rate
# Out:
# 1.0559316092509443
# 0.8756443451808897
# 0.8283632425829399

# %%
#long-term memory

# %%
print(H1_3 + H1_3)    #nikkei225+nikkei225
print(H2_3 + H2_3)    #volatility+volatility
print(H3_3 + H3_3)    #interest rate+interest rate
# Out:
# 1.1032127118488941
# 1.0086505066529945
# 0.6480759785128852

# %%
#Period 4: from February 2021 to January 2023

# %%
NIK225_4 = NIK225[1516:1975]
NIK_vol_4 = NIK_vol[1510:1986]
Interest_4 = Interest[1523:1986]

# %%
QvH_NIK225_4 = QvHurstEstimator(mbm_series=NIK225_4, alpha=0.2)
H1_4 = QvH_NIK225_4.holder_exponents.mean()
print(H1_4)
# Out:
# 0.5054878065668528

# %%
QvH_NIK_vol_4 = QvHurstEstimator(mbm_series=NIK_vol_4, alpha=0.2)
H2_4 = QvH_NIK_vol_4.holder_exponents.mean()
print(H2_4)
# Out:
# 0.3846547513195218

# %%
QvH_Interest_4 = QvHurstEstimator(mbm_series=Interest_4, alpha=0.2)
H3_4 = QvH_Interest_4.holder_exponents.mean()
print(H3_4)
# Out:
# 0.35035858995598385

# %%
#cross long-term memory

# %%
print(H1_4 + H2_4)    #nikkei225+volatility
print(H1_4 + H3_4)    #nikkei225+interest rate
print(H2_4 + H3_4)    #volatility+interest rate
# Out:
# 0.8901425578863746
# 0.8558463965228367
# 0.7350133412755057

# %%
#long-term memory

# %%
print(H1_4 + H1_4)    #nikkei225+nikkei225
print(H2_4 + H2_4)    #volatility+volatility
print(H3_4 + H3_4)    #interest rate+interest rate
# Out:
# 1.0109756131337055
# 0.7693095026390436
# 0.7007171799119677

# %%
#Period 5: from January 2023 to August 2024

# %%
NIK225_5 = NIK225[1976:2365]
NIK_vol_5 = NIK_vol[1987:2365]
Interest_5 = Interest[1987:2363]

# %%
QvH_NIK225_5 = QvHurstEstimator(mbm_series=NIK225_5, alpha=0.2)
H1_5 = QvH_NIK225_5.holder_exponents.mean()
print(H1_5)
# Out:
# 0.5344129519936458

# %%
QvH_NIK_vol_5 = QvHurstEstimator(mbm_series=NIK_vol_5, alpha=0.2)
H2_5 = QvH_NIK_vol_5.holder_exponents.mean()
print(H2_5)
# Out:
# 0.32675581581261315

# %%
QvH_Interest_5 = QvHurstEstimator(mbm_series=Interest_5, alpha=0.2)
H3_5 = QvH_Interest_5.holder_exponents.mean()
print(H3_5)
# Out:
# 0.43271007251808974

# %%
#cross long-term memory

# %%
print(H1_5 + H2_5)    #nikkei225+volatility
print(H1_5 + H3_5)    #nikkei225+interest rate
print(H2_5 + H3_5)    #volatility+interest rate
# Out:
# 0.861168767806259
# 0.9671230245117355
# 0.7594658883307028

# %%
#long-term memory

# %%
print(H1_5 + H1_5)    #nikkei225+nikkei225
print(H2_5 + H2_5)    #volatility+volatility
print(H3_5 + H3_5)    #interest rate+interest rate
# Out:
# 1.0688259039872916
# 0.6535116316252263
# 0.8654201450361795

# %%
#Period 6: from August 2024 to December 2025

# %%
NIK225_6 = NIK225[2366:]
NIK_vol_6 = NIK_vol[2366:]
Interest_6 = Interest[2364:]

# %%
QvH_NIK225_6 = QvHurstEstimator(mbm_series=NIK225_6, alpha=0.2)
H1_6 = QvH_NIK225_6.holder_exponents.mean()
print(H1_6)
# Out:
# 0.421508477961699

# %%
QvH_NIK_vol_6 = QvHurstEstimator(mbm_series=NIK_vol_6, alpha=0.2)
H2_6 = QvH_NIK_vol_6.holder_exponents.mean()
print(H2_6)
# Out:
# 0.3435115869439927

# %%
QvH_Interest_6 = QvHurstEstimator(mbm_series=Interest_6, alpha=0.2)
H3_6 = QvH_Interest_6.holder_exponents.mean()
print(H3_6)
# Out:
# 0.430165549596654

# %%
#cross long-term memory

# %%
print(H1_6 + H2_6)    #nikkei225+volatility
print(H1_6 + H3_6)    #nikkei225+interest rate
print(H2_6 + H3_6)    #volatility+interest rate
# Out:
# 0.7650200649056917
# 0.851674027558353
# 0.7736771365406467

# %%
#long-term memory

# %%
print(H1_6 + H1_6)    #nikkei225+nikkei225
print(H2_6 + H2_6)    #volatility+volatility
print(H3_6 + H3_6)    #interest rate+interest rate
# Out:
# 0.843016955923398
# 0.6870231738879854
# 0.860331099193308
