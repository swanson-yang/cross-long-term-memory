# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sp500 = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/SP500_daily_close_2014-12_to_2025-12_STOOQ.xlsx")
vix = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/VIX_daily_close_2014-12_to_2025-12_FRED.xlsx")
interest = pd.read_excel("C:/Users/14794/Desktop/Longterm memory/US_10Y_DGS10_daily_2014-12_to_2025-12.xlsx")

# %%
from fractal_analysis import estimator
from fractal_analysis.estimator.hurst_estimator import IrHurstEstimator, QvHurstEstimator

# %%
SP500=sp500['log_sp500']
VIX=vix['log_vix']
Interest=interest['log_interest']

# %%
a = sp500['Date']
y = SP500
x = pd.to_datetime(a)
plt.plot(x, y)
plt.plot([x[301], x[301]], [7.45, 8.9], color='red', linestyle='--', linewidth=0.8)
plt.annotate('02/2016',xy = (x[301],8.9), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1312], x[1312]], [7.45, 8.9], color='red', linestyle='--', linewidth=0.8)
plt.annotate('02/2020',xy = (x[1312],7.45), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1782], x[1782]], [7.45, 8.9], color='red', linestyle='--', linewidth=0.8)
plt.annotate('12/2021',xy = (x[1782],8.9), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1980], x[1980]], [7.45, 8.9], color='red', linestyle='--', linewidth=0.8)
plt.annotate('10/2022',xy = (x[1980],7.45), horizontalalignment = 'center', verticalalignment = 'top')
plt.title("S&P500")
plt.xlabel("Date")
plt.ylabel("S&P500 index")
plt.show()

# %%
b = interest['Date']
y = Interest
x = pd.to_datetime(b)
plt.plot(x, y)
plt.plot([x[300], x[300]], [-0.7, 1.7], color='red', linestyle='--', linewidth=1)
plt.annotate('02/2016',xy = (x[300],-0.7), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1295], x[1295]], [-0.7, 1.7], color='red', linestyle='--', linewidth=1)
plt.annotate('02/2020',xy = (x[1295],1.7), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1754], x[1754]], [-0.7, 1.7], color='red', linestyle='--', linewidth=1)
plt.annotate('12/2021',xy = (x[1754],-0.7), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1976], x[1976]], [-0.7, 1.7], color='red', linestyle='--', linewidth=1)
plt.annotate('10/2022',xy = (x[1976],1.7), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.title("Interest Rate")
plt.xlabel("Date")
plt.ylabel("10-year treasury yield")
plt.show()

# %%
c = vix['Date']
y = VIX
x = pd.to_datetime(c)
plt.plot(x, y)
plt.plot([x[301], x[301]], [2.1, 4.5], color='red', linestyle='--', linewidth=1)
plt.annotate('02/2016',xy = (x[301],4.5), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1308], x[1308]], [2.1, 4.5], color='red', linestyle='--', linewidth=1)
plt.annotate('02/2020',xy = (x[1308],2.1), horizontalalignment = 'center', verticalalignment = 'top')
plt.plot([x[1782], x[1782]], [2.1, 4.5], color='red', linestyle='--', linewidth=1)
plt.annotate('12/2021',xy = (x[1782],4.5), horizontalalignment = 'center', verticalalignment = 'bottom')
plt.plot([x[1983], x[1983]], [2.1, 4.5], color='red', linestyle='--', linewidth=1)
plt.annotate('10/2022',xy = (x[1983],2.1), horizontalalignment = 'center', verticalalignment = 'top')
plt.title("Volatility")
plt.xlabel("Date")
plt.ylabel("CBOE Volatility Index")
plt.show()

# %%
#Period 1: from December 2014 to February 2016

# %%
SP500_1 = SP500[0:301]
Interest_1 = Interest[0:300]
VIX_1 = VIX[0:301]

# %%
QvH_SP500_1 = QvHurstEstimator(mbm_series=SP500_1, alpha=0.2)
H1_1 = QvH_SP500_1.holder_exponents.mean()
print(H1_1)
# Out:
# 0.5483311998597864

# %%
QvH_VIX_1 = QvHurstEstimator(mbm_series=VIX_1, alpha=0.2)
H2_1 = QvH_VIX_1.holder_exponents.mean()
print(H2_1)
# Out:
# 0.5707771479601813

# %%
QvH_Interest_1 = QvHurstEstimator(mbm_series=Interest_1, alpha=0.2)
H3_1 = QvH_Interest_1.holder_exponents.mean()
print(H3_1)
# Out:
# 0.393822097009401

# %%
max_val = QvH_VIX_3.holder_exponents.max()
min_val = QvH_VIX_3.holder_exponents.min()
print(max_val, min_val)
# Out:
# 0.4583896909154528 0.34334722979974486

# %%
#cross long-term memory

# %%
print(H1_1 + H2_1)    #S&P500+volatility
print(H1_1 + H3_1)    #S&P500+interest rate
print(H2_1 + H3_1)    #volatility+interest rate
# Out:
# 1.1191083478199677
# 0.9421532968691875
# 0.9645992449695824

# %%
#long-term memory

# %%
print(H1_1 + H1_1)    #S&P500+S&P500
print(H2_1 + H2_1)    #volatility+volatility
print(H3_1 + H3_1)    #interest rate+interest rate
# Out:
# 1.0966623997195728
# 1.1415542959203626
# 0.787644194018802

# %%
#Period 2: from February 2016 to February 2020

# %%
SP500_2 = SP500[302:1312]
Interest_2 = Interest[301:1295]
VIX_2 = VIX[302:1308]

# %%
QvH_SP500_2 = QvHurstEstimator(mbm_series=SP500_2, alpha=0.2)
H1_2 = QvH_SP500_2.holder_exponents.mean()
print(H1_2)
# Out:
# 0.4597796431588888

# %%
QvH_VIX_2 = QvHurstEstimator(mbm_series=VIX_2, alpha=0.2)
H2_2 = QvH_VIX_2.holder_exponents.mean()
print(H2_2)
# Out:
# 0.4642212984528459

# %%
QvH_Interest_2 = QvHurstEstimator(mbm_series=Interest_2, alpha=0.2)
H3_2 = QvH_Interest_2.holder_exponents.mean()
print(H3_2)
# Out:
# 0.5213630543915521

# %%
#cross long-term memory

# %%
print(H1_2 + H2_2)    #S&P500+volatility
print(H1_2 + H3_2)    #S&P500+interest rate
print(H2_2 + H3_2)    #volatility+interest rate
# Out:
# 0.9240009416117347
# 0.9811426975504409
# 0.9855843528443979

# %%
#long-term memory

# %%
print(H1_2 + H1_2)    #S&P500+S&P500
print(H2_2 + H2_2)    #volatility+volatility
print(H3_2 + H3_2)    #interest rate+interest rate
# Out:
# 0.9195592863177776
# 0.9284425969056918
# 1.0427261087831041

# %%
#Period 3: from February 2020 to December 2021

# %%
SP500_3 = SP500[1313:1782]
Interest_3 = Interest[1296:1754]
VIX_3 = VIX[1309:1782]

# %%
QvH_SP500_3 = QvHurstEstimator(mbm_series=SP500_3, alpha=0.2)
H1_3 = QvH_SP500_3.holder_exponents.mean()
print(H1_3)
# Out:
# 0.4124228177434364

# %%
QvH_VIX_3 = QvHurstEstimator(mbm_series=VIX_3, alpha=0.2)
H2_3 = QvH_VIX_3.holder_exponents.mean()
print(H2_3)
# Out:
# 0.40852361895393374

# %%
QvH_Interest_3 = QvHurstEstimator(mbm_series=Interest_3, alpha=0.2)
H3_3 = QvH_Interest_3.holder_exponents.mean()
print(H3_3)
# Out:
# 0.4837343668273658

# %%
#cross long-term memory

# %%
print(H1_3 + H2_3)    #S&P500+volatility
print(H1_3 + H3_3)    #S&P500+interest rate
print(H2_3 + H3_3)    #volatility+interest rate
# Out:
# 0.8209464366973702
# 0.8961571845708023
# 0.8922579857812996

# %%
#long-term memory

# %%
print(H1_3 + H1_3)    #S&P500+S&P500
print(H2_3 + H2_3)    #volatility+volatility
print(H3_3 + H3_3)    #interest rate+interest rate
# Out:
# 0.8248456354868728
# 0.8170472379078675
# 0.9674687336547316

# %%
#Period 4: from December 2021 to October 2022

# %%
SP500_4 = SP500[1783:1980]
Interest_4 = Interest[1755:1976]
VIX_4 = VIX[1783:1983]

# %%
QvH_SP500_4 = QvHurstEstimator(mbm_series=SP500_4, alpha=0.2)
H1_4 = QvH_SP500_4.holder_exponents.mean()
print(H1_4)
# Out:
# 0.5250478564843706

# %%
QvH_VIX_4 = QvHurstEstimator(mbm_series=VIX_4, alpha=0.2)
H2_4 = QvH_VIX_4.holder_exponents.mean()
print(H2_4)
# Out:
# 0.4197322151795235

# %%
QvH_Interest_4 = QvHurstEstimator(mbm_series=Interest_4, alpha=0.2)
H3_4 = QvH_Interest_4.holder_exponents.mean()
print(H3_4)
# Out:
# 0.4247163276910827

# %%
#cross long-term memory

# %%
print(H1_4 + H2_4)    #S&P500+volatility
print(H1_4 + H3_4)    #S&P500+interest rate
print(H2_4 + H3_4)    #volatility+interest rate
# Out:
# 0.9447800716638941
# 0.9497641841754533
# 0.8444485428706062

# %%
#long-term memory

# %%
print(H1_4 + H1_4)    #S&P500+S&P500
print(H2_4 + H2_4)    #volatility+volatility
print(H3_4 + H3_4)    #interest rate+interest rate
# Out:
# 1.0500957129687412
# 0.839464430359047
# 0.8494326553821654

# %%
#Period 5: from October 2022 to the December 2025

# %%
SP500_5 = SP500[1981:]
Interest_5 = Interest[1977:]
VIX_5 = VIX[1984:]

# %%
QvH_SP500_5 = QvHurstEstimator(mbm_series=SP500_5, alpha=0.2)
H1_5 = QvH_SP500_5.holder_exponents.mean()
print(H1_5)
# Out:
# 0.49057029928826074

# %%
QvH_VIX_5 = QvHurstEstimator(mbm_series=VIX_5, alpha=0.2)
H2_5 = QvH_VIX_5.holder_exponents.mean()
print(H2_5)
# Out:
# 0.5042300401774694

# %%
QvH_Interest_5 = QvHurstEstimator(mbm_series=Interest_5, alpha=0.2)
H3_5 = QvH_Interest_5.holder_exponents.mean()
print(H3_5)
# Out:
# 0.488770122959832

# %%
#cross long-term memory

# %%
print(H1_5 + H2_5)    #S&P500+volatility
print(H1_5 + H3_5)    #S&P500+interest rate
print(H2_5 + H3_5)    #volatility+interest rate
# Out:
# 0.9948003394657301
# 0.9793404222480928
# 0.9930001631373014

# %%
#long-term memory

# %%
print(H1_5 + H1_5)    #S&P500+S&P500
print(H2_5 + H2_5)    #volatility+volatility
print(H3_5 + H3_5)    #interest rate+interest rate
# Out:
# 0.9811405985765215
# 1.0084600803549388
# 0.977540245919664
